# %%
import pandas as pd

df = pd.read_csv('sales.csv')

# %%
# Fetch first 5 rows
df.head()
# Out:
#          Date   Category   Value Product  Sales Region
# 0  2024-06-04   Clothing  190.47   Jeans   35.0  North
# 1  2024-02-23       Toys  315.70    Doll   29.0   West
# 2  2024-09-25  Furniture  104.65   Table    2.0   East
# 3  2024-12-27       Toys  134.77  Puzzle    6.0   West
# 4  2024-06-05       Toys  143.32    Doll   18.0  North

# %%
# Fetch last five rows
df.tail()
# Out:
#            Date     Category   Value     Product  Sales Region
# 495  2024-06-30     Clothing  305.66       Dress   44.0  South
# 496  2024-12-14    Furniture   19.40       Chair   45.0  North
# 497  2024-09-23  Electronics   31.26  Smartwatch   44.0  North
# 498  2024-11-25     Clothing  463.53     T-shirt   18.0   East
# 499  2024-05-27    Groceries   91.36        Eggs   31.0  South

# %%
# describe the data
df.describe()
# Out:
#             Value       Sales
# count  450.000000  450.000000
# mean   238.938600   25.762222
# std    139.960648   14.692055
# min     10.090000    1.000000
# 25%    118.915000   13.000000
# 50%    223.920000   26.000000
# 75%    348.657500   39.000000
# max    498.890000   50.000000

# %%
# Data types of data
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
# Handling missing values

# Check which column has missing values
df.isnull().any()

# Retrieve the entire rows to see which one has missing values
df.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
# Total number of missing values in each column
df.isnull().sum()
# Out:
# Date         0
# Category     0
# Value       50
# Product      0
# Sales       50
# Region       0
# dtype: int64

# %%
# Replace all missing values with 0
# Always create a copy of column before filling missing values
df_filled = df.fillna(0)

# %%
# Replace missing values with the mean of the column
df['Sales_fillNA'] = df['Sales'].fillna(df['Sales'].mean())

# %%
# Renaming a column
df = df.rename(columns={'Sale Date' : 'Sales Date'})
df.head()
# Out:
#          Date   Category   Value Product  Sales Region  Sales_fillNA
# 0  2024-06-04   Clothing  190.47   Jeans   35.0  North          35.0
# 1  2024-02-23       Toys  315.70    Doll   29.0   West          29.0
# 2  2024-09-25  Furniture  104.65   Table    2.0   East           2.0
# 3  2024-12-27       Toys  134.77  Puzzle    6.0   West           6.0
# 4  2024-06-05       Toys  143.32    Doll   18.0  North          18.0

# %%
# Change data types of a specific column
df['Value_new'] = df['Value'].fillna(df['Value'].mean()).astype(int)
df.head()
# Out:
#          Date   Category   Value Product  Sales Region  Sales_fillNA  \
# 0  2024-06-04   Clothing  190.47   Jeans   35.0  North          35.0
# 1  2024-02-23       Toys  315.70    Doll   29.0   West          29.0
# 2  2024-09-25  Furniture  104.65   Table    2.0   East           2.0
# 3  2024-12-27       Toys  134.77  Puzzle    6.0   West           6.0
# 4  2024-06-05       Toys  143.32    Doll   18.0  North          18.0
#
#    Value_new
# 0        190
# 1        315
# 2        104
# 3        134
# 4        143

# %%
# Apply function to a specific column
df['New Value'] = df['Value'].apply(lambda x: x*2)
df.head()
# Out:
#          Date   Category   Value Product  Sales Region  Sales_fillNA  \
# 0  2024-06-04   Clothing  190.47   Jeans   35.0  North          35.0
# 1  2024-02-23       Toys  315.70    Doll   29.0   West          29.0
# 2  2024-09-25  Furniture  104.65   Table    2.0   East           2.0
# 3  2024-12-27       Toys  134.77  Puzzle    6.0   West           6.0
# 4  2024-06-05       Toys  143.32    Doll   18.0  North          18.0
#
#    Value_new  New Value
# 0        190     380.94
# 1        315     631.40
# 2        104     209.30
# 3        134     269.54
# 4        143     286.64

# %%
# Data Aggregating and Grouping

df.head()
# Out:
#          Date   Category   Value Product  Sales Region  Sales_fillNA  \
# 0  2024-06-04   Clothing  190.47   Jeans   35.0  North          35.0
# 1  2024-02-23       Toys  315.70    Doll   29.0   West          29.0
# 2  2024-09-25  Furniture  104.65   Table    2.0   East           2.0
# 3  2024-12-27       Toys  134.77  Puzzle    6.0   West           6.0
# 4  2024-06-05       Toys  143.32    Doll   18.0  North          18.0
#
#    Value_new  New Value
# 0        190     380.94
# 1        315     631.40
# 2        104     209.30
# 3        134     269.54
# 4        143     286.64

# %%
# Aggregation based on grouping

# Here we have find out the means based on the product category
grouped_mean = df.groupby('Product')['Value'].mean()

print(grouped_mean)
# Out:
# Product
# Action Figure    249.870667
# Bed              218.598667
# Board Game       185.153889
# Bookshelf        291.428750
# Bread            262.189286
# Chair            222.740000
# Doll             251.509500
# Dress            243.467273
# Eggs             270.104545
# Fruits           215.639048
# Headphones       201.879545
# Jacket           195.655294
# Jeans            233.960000
# Laptop           237.125833
# Lego             238.396316
# Milk             264.734118
# Puzzle           263.220476
# Shoes            232.362000
# Smartphone       236.958077
# Smartwatch       198.807500
# Sofa             238.400870
# T-shirt          272.122857
# Table            252.858500
# Tablet           298.274000
# Vegetables       226.885625
# Name: Value, dtype: float64

# %%
# Total sales of product region wise

grouped_sum = df.groupby(['Product', 'Region'])['Value'].sum()
print(grouped_sum)
# Out:
# Product        Region
# Action Figure  East      1497.73
#                North     1717.53
#                West       532.80
# Bed            East      1147.10
#                North        0.00
#                           ...
# Tablet         West      1741.90
# Vegetables     East       727.68
#                North      363.85
#                South      844.34
#                West      1694.30
# Name: Value, Length: 99, dtype: float64

# %%
# aggregate multiple functions
grouped_agg = df.groupby('Region')['Value'].agg(['mean', 'sum', 'count'])
print(grouped_agg)
# Out:
#               mean       sum  count
# Region
# East    232.420190  24404.12    105
# North   266.683900  26668.39    100
# South   221.095872  24099.45    109
# West    237.870662  32350.41    136

# %%
# Merging and joining dataframes

df1 = pd.DataFrame({'Key': ['A', 'B', 'C'], 'Value1': [1, 2, 3]})
df2 = pd.DataFrame({'Key': ['A', 'B', 'D'], 'Value2': [4, 5, 6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
# Merge data frames on the 'key' column

pd.merge(df1, df2, on='Key', how='inner')
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1, df2, on='Key', how='outer')
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1, df2, on='Key', how='left')
# Out:
#   Key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1, df2, on='Key', how='right')
# Out:
#   Key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6
